# %% [markdown]
# # Insertar fondo transparente a imagen

# %% [markdown]
# ## Parte 1, cambiar a blanco el color de fondo

# %% [markdown]
# Importamos las librerías

# %%
import numpy as np
import imageio
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Abrimos la imagen y capturamos su altura y anchura

# %%
nombre_fichero = cv2.imread("image.png")

h, w = nombre_fichero.shape[:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f32f6c82db06> in <module>()
#       1 nombre_fichero = cv2.imread("image.jpeg")
#       2
# ----> 3 h, w = nombre_fichero.shape[:2]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# Mostramos por pantalla la imagen, debido a que plt utiliza los filtros RGB y cv2 BGR debemos realizar un cambio de orden.

# %%
plt.imshow( cv2.cvtColor(nombre_fichero, cv2.COLOR_BGR2RGBA) )
print("Estructura: ",nombre_fichero.shape)
# Out:
# Estructura:  (1024, 1280, 3)

# %% [markdown]
# Creamos una matriz de ceros dos píxeles más grande en altura y anchura

# %%
mask = np.zeros((h+2, w+2), dtype = np.uint8)

# %% [markdown]
# El método `.floodFill()` rellena un objeto conectado con un color dado.
# -  El primer argumento especifica la entrada, la imagen a rellenar
# -  El segundo argumento, `mask` debe ser una imagen de 8 bits de un solo canal, 2 píxeles mas ancha y alta que la imagen.
# -  El píxel inicial, el color de ese píxel será el que conectaremos con los demás píxeles
# -  El color del píxel nuevo
# -  Máxima diferencia __inferior__ de color entre el píxel observado y el de uno de sus vecinos que pertenezcan al componente
# -  Máxima diferencia __superior__ de color entre el píxel observado y el de uno de sus vecinos que pertenezcan al componente.

# %%
dif_valor = 6  #Este valor es distinto para cada imagen
diff = (dif_valor, dif_valor, dif_valor)

# %%
cv2.floodFill(nombre_fichero, mask, (200,10), (255, 255, 255), diff, diff)

print(nombre_fichero.shape)
plt.imshow(cv2.cvtColor(nombre_fichero, cv2.COLOR_BGR2RGB))
plt.figure()
# Out:
# (1024, 1280, 3)

# %% [markdown]
# ## Parte 2.1, trasformar fondo blanco a fondo transparente

# %% [markdown]
# A partir de una imagen con fondo blanco transformamos los píxeles blancos en transparentes mediante la librería Image, transformamos nuestra imagen de tipo cv2 a tipo Image

# %%
img = Image.fromarray(cv2.cvtColor(nombre_fichero, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Transformamos la imagen RGB a RGBA, la variable A define la opacidad del píxel, por lo que para ciertos píxeles insertaremos opacidad 0.

# %%
img = img.convert("RGBA")

# %%
datas = img.getdata()

# %% [markdown]
# Creamos variable newData donde insertaremos los píxeles de la nueva imagen

# %%
newData = []

# %% [markdown]
# Recorremos todos los píxeles de la imagen, donde el valor del píxel sea totalmente blanco (255, 255, 255) ponemos intensidad 0.

# %%
for item in datas:
    if item[0] == 255 and item[1] == 255 and item[2] == 255:
        newData.append((255,255,255,0))
    else:
        newData.append(item)

# %% [markdown]
# Guardamos la imagen

# %%
img.putdata(newData)
img.save("transparentBackgroundImage.png", "PNG")

# %% [markdown]
# ## Parte 2.2 Otra forma transformar fondo blanco a transparente

# %% [markdown]
# Transformamos la imagen a una matriz mediante la librería `numpy`

# %%
imagen1 = np.array(Image.fromarray(cv2.cvtColor(nombre_fichero, cv2.COLOR_BGR2RGBA)))

# %%
altura, anchura = imagen1.shape[:2]

# %% [markdown]
# Realizamos una copia de nuestra imagen actual

# %%
imagenSinFondo = imagen1

# %% [markdown]
# Si encontramos un píxel de color blanco total (255, 255, 255) le asignamos opacidad 0.

# %%
for i in range(altura):
    for j in range(anchura):
        if (imagenSinFondo[i,j,0] == 255 and imagenSinFondo[i,j,1] == 255 and imagenSinFondo[i,j,2] == 255 ):
            imagenSinFondo[i,j,3] = 0

# %% [markdown]
# Guardamos la imagen mediante la librería `imageio`

# %%
imageio.imwrite('transparentBackgroundImage2.png', imagenSinFondo)
